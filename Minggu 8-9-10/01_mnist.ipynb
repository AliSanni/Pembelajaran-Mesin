# %%
from tensorflow.keras.datasets import mnist

# %%
# the data, split between train and validation sets
(x_train, y_train), (x_valid, y_valid) = mnist.load_data()

# %%
x_train.shape

# %%
x_valid.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/4006754794.py in <cell line: 0>()
# ----> 1 x_valid.shape
#
# NameError: name 'x_valid' is not defined

# %%
x_train.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/3778083001.py in <cell line: 0>()
# ----> 1 x_train.dtype
#
# NameError: name 'x_train' is not defined

# %%
x_train.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/2297747828.py in <cell line: 0>()
# ----> 1 x_train.min()
#
# NameError: name 'x_train' is not defined

# %%
x_train.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/2169750212.py in <cell line: 0>()
# ----> 1 x_train.max()
#
# NameError: name 'x_train' is not defined

# %%
x_train[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/1465205078.py in <cell line: 0>()
# ----> 1 x_train[0]
#
# NameError: name 'x_train' is not defined

# %%
import matplotlib.pyplot as plt

image = x_train[0]
plt.imshow(image, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/1089057528.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 image = x_train[0]
#       4 plt.imshow(image, cmap='gray')
#
# NameError: name 'x_train' is not defined

# %%
y_train[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/2332557866.py in <cell line: 0>()
# ----> 1 y_train[0]
#
# NameError: name 'y_train' is not defined

# %%
x_train = x_train.reshape(60000, 784)
x_valid = x_valid.reshape(10000, 784)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/1218574403.py in <cell line: 0>()
# ----> 1 x_train = x_train.reshape(60000, 784)
#       2 x_valid = x_valid.reshape(10000, 784)
#
# NameError: name 'x_train' is not defined

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/2512218947.py in <cell line: 0>()
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
x_train[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/1465205078.py in <cell line: 0>()
# ----> 1 x_train[0]
#
# NameError: name 'x_train' is not defined

# %%
x_train = x_train / 255
x_valid = x_valid / 255
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/2422501828.py in <cell line: 0>()
# ----> 1 x_train = x_train / 255
#       2 x_valid = x_valid / 255
#
# NameError: name 'x_train' is not defined

# %%
x_train.dtype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/3778083001.py in <cell line: 0>()
# ----> 1 x_train.dtype
#
# NameError: name 'x_train' is not defined

# %%
x_train.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/2297747828.py in <cell line: 0>()
# ----> 1 x_train.min()
#
# NameError: name 'x_train' is not defined

# %%
x_train.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_436/2169750212.py in <cell line: 0>()
# ----> 1 x_train.max()
#
# NameError: name 'x_train' is not defined
